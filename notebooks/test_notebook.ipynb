# %%
import os

import numpy as np
import pandas as pd

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from catboost import CatBoostClassifier

from xgboost import XGBClassifier


from skactiveml.classifier import SklearnClassifier
from skactiveml.stream import (
    FixedUncertainty,
    VariableUncertainty,
    Split,
    StreamProbabilisticAL,
    StreamRandomSampling,
    PeriodicSampling,
    RandomVariableUncertainty,
    StreamDensityBasedAL,
    CognitiveDualQueryStrategyRan,
    CognitiveDualQueryStrategyFixUn,
    CognitiveDualQueryStrategyRanVarUn,
    CognitiveDualQueryStrategyVarUn,
)
from skactiveml.utils import call_func

from datetime import datetime
import pytz

import warnings
warnings.filterwarnings('ignore')

# %%
tz_utc_minus_3 = pytz.timezone("America/Sao_Paulo")

# %%
init_train_ratio = 0.1
stream_ratio = 0.9

# %%
def custom_accuracy(y_true, y_pred):
    return np.mean(np.array(y_true) == np.array(y_pred))

# %%
class WrappedXGBClassifier(XGBClassifier):
    def fit(self, X, y, **kwargs):
        return super().fit(X, y, **kwargs)
    def predict(self,X, **kwargs):
        return super().predict(X, **kwargs)
    def predict_proba(self, X, **kwargs):
        return super().predict_proba(X, **kwargs)
    def score(self, X, y, **kwargs):
        return super().score(X, y, **kwargs)

class WrappedCatBoostClassifier(CatBoostClassifier):
    def fit(self, X, y, **kwargs):
        return super().fit(X, y, **kwargs)

    def predict(self, X, **kwargs):
        return super().predict(X, **kwargs)

    def predict_proba(self, X, **kwargs):
        return super().predict_proba(X, **kwargs)

    def score(self, X, y, **kwargs):
        return super().score(X, y, **kwargs)

# %%
datasets_dict = {
    # 'Elect2': {'path': '../data/tests/electricity.csv',
    #            'header':'infer',
    #            'y':'class',
    #            'X':['date', 'day', 'period', 'nswprice', 'nswdemand', 'vicprice', 'vicdemand', 'transfer']
    #            },
     'iris': {'path': '../data/tests/iris.csv',
              'header':None,
              'y': 3,
              'X': [0, 1, 2]}
}

models = {
    'LogisticRegression': {
        'model': LogisticRegression(max_iter=10000, random_state=0),
        'params': {
            'C': [0.001, 0.01, 0.1, 0.5, 1, 5, 10, 100]
        }
    },
    'XGBoost': {
        'model': XGBClassifier(random_state=0),
        'params': {
            'max_depth': [3, 6, 9],
            'learning_rate': [0.01, 0.1, 0.2],
            'n_estimators': [100, 300, 500],
            'gamma': [0, 0.1, 0.2],
            'reg_lambda': [0, 1, 10],
            'reg_alpha': [0, 1, 10]
        }
    },
    'SVM': {
        'model': SVC(kernel = 'rbf', probability = True, random_state=0),
        'params': {
            'C': [0.1, 1, 10, 100],
            'gamma': ['scale', 'auto']
        }
    },
    'DecisionTree': {
        'model': DecisionTreeClassifier(random_state=0),
        'params': {
            'max_depth': [None, 5, 10, 20],
            'min_samples_split': [2, 5, 10],
            'min_samples_leaf': [1, 2, 5]
        }
    },
    'RandomForest': {
        'model': RandomForestClassifier(random_state=0),
        'params': {
            'n_estimators': [100, 200, 500],
            'max_depth': [None, 10, 20],
            'min_samples_split': [2, 5, 10],
            'min_samples_leaf': [1, 2, 5]
        }
    },
    'CatBoost': {
        'model': CatBoostClassifier(random_state=0, allow_writing_files=False, thread_count = -1, verbose = 0),
        'params': {
            'depth': [4, 6, 10],
            'learning_rate': [0.01, 0.1, 0.2],
            'iterations': [100, 500, 1000]
        }
    }
}

budgets = [0.05, 0.1, 0.2, 0.5, 1.0]

# %%
results_path = '../data/results/test'

# %%
results_df = pd.DataFrame()

for dataset in datasets_dict.keys():
    print(f'Dataset: {dataset}')
    df = pd.read_csv(
        datasets_dict[dataset]['path'],
        header =  datasets_dict[dataset]['header']
        )

    X = df[datasets_dict[dataset]['X']]

    y = df[datasets_dict[dataset]['y']]

    X_init_train = X.iloc[:round(X.shape[0]*init_train_ratio)]
    y_init_train = y.iloc[:round(y.shape[0]*init_train_ratio)]

    X_stream = X.iloc[round(X.shape[0]*init_train_ratio):round(X.shape[0]*stream_ratio)]
    y_stream = y.iloc[round(y.shape[0]*init_train_ratio):round(y.shape[0]*stream_ratio)]

    X_stream = X_stream.to_numpy()
    y_stream = y_stream.to_numpy()

    X_final_val = X.iloc[round(X.shape[0]*stream_ratio):]
    y_final_val = y.iloc[round(y.shape[0]*stream_ratio):]

    for model_name, model_config in models.items():
        print(f'\tModel: {model_name} - {datetime.now(tz_utc_minus_3).strftime("%H:%M:%S")}')

        grid_search = GridSearchCV(model_config['model'], model_config['params'], cv=5, scoring='accuracy', n_jobs=-1, error_score = 'raise', refit=True)
        grid_search.fit(X_init_train, y_init_train)

        X_final_train = X_init_train
        y_final_train = y_init_train

        if model_name == 'XGBoost':
            pretrained_model = WrappedXGBClassifier(grid_search.best_estimator_)
        elif model_name == 'CatBoost':
            pretrained_model = WrappedCatBoostClassifier(grid_search.best_estimator_)
        else:
            pretrained_model = grid_search.best_estimator_

        clf_factory = lambda: SklearnClassifier(pretrained_model)

        clf_inicial = clf_factory().fit(X_init_train, y_init_train)

        y_pred = clf_inicial.predict(X_final_val)

        initial_accuracy = custom_accuracy(y_final_val, y_pred)

        for budget in budgets:
            print(f'\t\tBudget: {budget} - {datetime.now(tz_utc_minus_3).strftime("%H:%M:%S")}')
            query_strategies = {
                'FixedUncertainty': FixedUncertainty(budget=budget, random_state=0),
                'VariableUncertainty': VariableUncertainty(budget=budget, random_state=0),
                'Split': Split(budget=budget, random_state=0),
                'StreamProbabilisticAL': StreamProbabilisticAL(budget=budget, metric = 'rbf', random_state=0),
                'StreamRandomSampling': StreamRandomSampling(budget=budget, random_state=0),
                'PeriodicSampling': PeriodicSampling(budget=budget, random_state=0),
                'RandomVariableUncertainty': RandomVariableUncertainty(budget=budget, random_state=0),
                'StreamDensityBasedAL': StreamDensityBasedAL(budget=budget, random_state=0),
                'CognitiveDualQueryStrategyRan': CognitiveDualQueryStrategyRan(budget=budget, random_state=0),
                'CognitiveDualQueryStrategyFixUn': CognitiveDualQueryStrategyFixUn(budget=budget, random_state=0),
                'CognitiveDualQueryStrategyRanVarUn': CognitiveDualQueryStrategyRanVarUn(budget=budget, random_state=0),
                'CognitiveDualQueryStrategyVarUn': CognitiveDualQueryStrategyVarUn(budget=budget, random_state=0),
            }

            if budget == 1.0:
                X_final_train = pd.concat([X_init_train, pd.DataFrame(X_stream)], axis = 0, ignore_index=True)
                y_final_train = pd.concat([y_init_train, pd.Series(y_stream)], axis = 0, ignore_index=True)

                clf = clf_factory()

                final_trained_model = clf.fit(X_final_train, y_final_train)

                y_pred = final_trained_model.predict(X_final_val)

                final_accuracy = custom_accuracy(y_final_val, y_pred)

                experiment_result = pd.DataFrame(data = {
                        'dataset': [dataset],
                        'model_name': [model_name],
                        'model_params': [str(grid_search.best_params_)],
                        'initial_score': [initial_accuracy],
                        'query_strategy': 'NONE: BUDGET = 1',
                        'budget': [budget],
                        'percentage_queried': [(X_final_train.shape[0] - X_init_train.shape[0])/(X_stream.shape[0])],
                        'final_accuracy': [final_accuracy]
                    })

                results_df = pd.concat([results_df, experiment_result], axis = 0)
                results_df.to_csv(f'{results_path}/test_results.csv')

            else:
                for query_strategy_name, query_strategy in query_strategies.items():
                    print(f'\t\t\tQuery strategy: {query_strategy_name} - {datetime.now(tz_utc_minus_3).strftime("%H:%M:%S")}')

                    X_final_train = X_init_train.to_numpy()
                    y_final_train = y_init_train.to_numpy()

                    new_X, new_y = [], []

                    for i in range(len(X_stream)):
                        x_cand = X_stream[i].reshape(1,-1)
                        y_cand = y_stream[i].reshape(1,)


                        if query_strategy_name in ('StreamProbabilisticAL'):
                            queried_indices, utilities = query_strategy.query(
                                candidates=x_cand,
                                clf=clf_inicial,
                                X=X_init_train,
                                y=y_init_train,
                                return_utilities=True,
                                fit_clf=False
                            )
                        else:
                            queried_indices, utilities = call_func(
                                query_strategy.query,
                                candidates=x_cand,
                                clf=clf_inicial,
                                return_utilities=True,
                                fit_clf=False
                            )

                        budget_manager_param_dict = {"utilities": utilities}

                        call_func(query_strategy.update,
                                    candidates = x_cand,
                                    queried_indices = queried_indices,
                                    budget_manager_param_dict=budget_manager_param_dict)

                        if len(queried_indices):
                            new_X.append(x_cand)
                            new_y.append(y_cand)

                    if new_X:
                        X_final_train = np.vstack([X_final_train] + new_X)
                        y_final_train = np.concatenate([y_final_train] + new_y, axis=0)

                    clf = clf_factory()

                    X_final_train = pd.DataFrame(X_final_train, columns=X_init_train.columns)
                    y_final_train = pd.Series(y_final_train.flatten())

                    final_trained_model = clf.fit(X_final_train, y_final_train)

                    y_pred = final_trained_model.predict(X_final_val)

                    final_accuracy = custom_accuracy(y_final_val, y_pred)

                    experiment_result = pd.DataFrame(data = {
                        'dataset': [dataset],
                        'model_name': [model_name],
                        'model_params': [str(grid_search.best_params_)],
                        'initial_score': [initial_accuracy],
                        'query_strategy': [query_strategy_name],
                        'budget': [budget],
                        'percentage_queried': [(X_final_train.shape[0] - X_init_train.shape[0])/(X_stream.shape[0])],
                        'final_accuracy': [final_accuracy]
                    })

                    results_df = pd.concat([results_df, experiment_result], axis = 0)
                    results_df.to_csv(f'{results_path}/test_results.csv')
# Out:
# Dataset: iris
# 	Model: LogisticRegression - 01:09:55
# 		Budget: 0.05 - 01:09:56
# 			Query strategy: FixedUncertainty - 01:09:56
# 			Query strategy: VariableUncertainty - 01:09:57
# 			Query strategy: Split - 01:09:57
# 			Query strategy: StreamProbabilisticAL - 01:09:57
# 			Query strategy: StreamRandomSampling - 01:09:57
# 			Query strategy: PeriodicSampling - 01:09:57
# 			Query strategy: RandomVariableUncertainty - 01:09:57
# 			Query strategy: StreamDensityBasedAL - 01:09:57
# 			Query strategy: CognitiveDualQueryStrategyRan - 01:09:58
# 			Query strategy: CognitiveDualQueryStrategyFixUn - 01:09:58
# 			Query strategy: CognitiveDualQueryStrategyRanVarUn - 01:09:58
# 			Query strategy: CognitiveDualQueryStrategyVarUn - 01:09:58
# 		Budget: 0.1 - 01:09:58
# 			Query strategy: FixedUncertainty - 01:09:58
# 			Query strategy: VariableUncertainty - 01:09:58
# 			Query strategy: Split - 01:09:58
# 			Query strategy: StreamProbabilisticAL - 01:09:58
# 			Query strategy: StreamRandomSampling - 01:09:58
# 			Query strategy: PeriodicSampling - 01:09:58
# 			Query strategy: RandomVariableUncertainty - 01:09:58
# 			Query strategy: StreamDensityBasedAL - 01:09:59
# 			Query strategy: CognitiveDualQueryStrategyRan - 01:09:59
# 			Query strategy: CognitiveDualQueryStrategyFixUn - 01:09:59
# 			Query strategy: CognitiveDualQueryStrategyRanVarUn - 01:09:59
# 			Query strategy: CognitiveDualQueryStrategyVarUn - 01:09:59
# 		Budget: 0.2 - 01:09:59
# 			Query strategy: FixedUncertainty - 01:09:59
# 			Query strategy: VariableUncertainty - 01:09:59
# 			Query strategy: Split - 01:09:59
# 			Query strategy: StreamProbabilisticAL - 01:09:59
# 			Query strategy: StreamRandomSampling - 01:10:00
# 			Query strategy: PeriodicSampling - 01:10:00
# 			Query strategy: RandomVariableUncertainty - 01:10:00
# 			Query strategy: StreamDensityBasedAL - 01:10:00
# 			Query strategy: CognitiveDualQueryStrategyRan - 01:10:00
# 			Query strategy: CognitiveDualQueryStrategyFixUn - 01:10:00
# 			Query strategy: CognitiveDualQueryStrategyRanVarUn - 01:10:00
# 			Query strategy: CognitiveDualQueryStrategyVarUn - 01:10:00
# 		Budget: 0.5 - 01:10:00
# 			Query strategy: FixedUncertainty - 01:10:00
# 			Query strategy: VariableUncertainty - 01:10:00
# 			Query strategy: Split - 01:10:00
# 			Query strategy: StreamProbabilisticAL - 01:10:00
# 			Query strategy: StreamRandomSampling - 01:10:01
# 			Query strategy: PeriodicSampling - 01:10:01
# 			Query strategy: RandomVariableUncertainty - 01:10:01
# 			Query strategy: StreamDensityBasedAL - 01:10:01
# 			Query strategy: CognitiveDualQueryStrategyRan - 01:10:01
# 			Query strategy: CognitiveDualQueryStrategyFixUn - 01:10:01
# 			Query strategy: CognitiveDualQueryStrategyRanVarUn - 01:10:01
# 			Query strategy: CognitiveDualQueryStrategyVarUn - 01:10:01
# 		Budget: 1.0 - 01:10:01
# 	Model: XGBoost - 01:10:01
# 		Budget: 0.05 - 01:10:12
# 			Query strategy: FixedUncertainty - 01:10:12
# 			Query strategy: VariableUncertainty - 01:10:12
# 			Query strategy: Split - 01:10:13
# 			Query strategy: StreamProbabilisticAL - 01:10:13
# 			Query strategy: StreamRandomSampling - 01:10:13
# 			Query strategy: PeriodicSampling - 01:10:13
# 			Query strategy: RandomVariableUncertainty - 01:10:13
# 			Query strategy: StreamDensityBasedAL - 01:10:14
# 			Query strategy: CognitiveDualQueryStrategyRan - 01:10:14
# 			Query strategy: CognitiveDualQueryStrategyFixUn - 01:10:14
# 			Query strategy: CognitiveDualQueryStrategyRanVarUn - 01:10:14
# 			Query strategy: CognitiveDualQueryStrategyVarUn - 01:10:15
# 		Budget: 0.1 - 01:10:15
# 			Query strategy: FixedUncertainty - 01:10:15
# 			Query strategy: VariableUncertainty - 01:10:15
# 			Query strategy: Split - 01:10:15
# 			Query strategy: StreamProbabilisticAL - 01:10:15
# 			Query strategy: StreamRandomSampling - 01:10:16
# 			Query strategy: PeriodicSampling - 01:10:16
# 			Query strategy: RandomVariableUncertainty - 01:10:16
# 			Query strategy: StreamDensityBasedAL - 01:10:16
# 			Query strategy: CognitiveDualQueryStrategyRan - 01:10:16
# 			Query strategy: CognitiveDualQueryStrategyFixUn - 01:10:17
# 			Query strategy: CognitiveDualQueryStrategyRanVarUn - 01:10:17
# 			Query strategy: CognitiveDualQueryStrategyVarUn - 01:10:17
# 		Budget: 0.2 - 01:10:18
# 			Query strategy: FixedUncertainty - 01:10:18
# 			Query strategy: VariableUncertainty - 01:10:18
# 			Query strategy: Split - 01:10:18
# 			Query strategy: StreamProbabilisticAL - 01:10:18
# 			Query strategy: StreamRandomSampling - 01:10:19
# 			Query strategy: PeriodicSampling - 01:10:19
# 			Query strategy: RandomVariableUncertainty - 01:10:19
# 			Query strategy: StreamDensityBasedAL - 01:10:19
# 			Query strategy: CognitiveDualQueryStrategyRan - 01:10:19
# 			Query strategy: CognitiveDualQueryStrategyFixUn - 01:10:19
# 			Query strategy: CognitiveDualQueryStrategyRanVarUn - 01:10:20
# 			Query strategy: CognitiveDualQueryStrategyVarUn - 01:10:20
# 		Budget: 0.5 - 01:10:20
# 			Query strategy: FixedUncertainty - 01:10:20
# 			Query strategy: VariableUncertainty - 01:10:20
# 			Query strategy: Split - 01:10:21
# 			Query strategy: StreamProbabilisticAL - 01:10:21
# 			Query strategy: StreamRandomSampling - 01:10:21
# 			Query strategy: PeriodicSampling - 01:10:21
# 			Query strategy: RandomVariableUncertainty - 01:10:21
# 			Query strategy: StreamDensityBasedAL - 01:10:22
# 			Query strategy: CognitiveDualQueryStrategyRan - 01:10:22
# 			Query strategy: CognitiveDualQueryStrategyFixUn - 01:10:22
# 			Query strategy: CognitiveDualQueryStrategyRanVarUn - 01:10:22
# 			Query strategy: CognitiveDualQueryStrategyVarUn - 01:10:23
# 		Budget: 1.0 - 01:10:23
# 	Model: SVM - 01:10:23
# 		Budget: 0.05 - 01:10:23
# 			Query strategy: FixedUncertainty - 01:10:23
# 			Query strategy: VariableUncertainty - 01:10:23
# 			Query strategy: Split - 01:10:24
# 			Query strategy: StreamProbabilisticAL - 01:10:24
# 			Query strategy: StreamRandomSampling - 01:10:24
# 			Query strategy: PeriodicSampling - 01:10:24
# 			Query strategy: RandomVariableUncertainty - 01:10:24
# 			Query strategy: StreamDensityBasedAL - 01:10:24
# 			Query strategy: CognitiveDualQueryStrategyRan - 01:10:24
# 			Query strategy: CognitiveDualQueryStrategyFixUn - 01:10:24
# 			Query strategy: CognitiveDualQueryStrategyRanVarUn - 01:10:24
# 			Query strategy: CognitiveDualQueryStrategyVarUn - 01:10:24
# 		Budget: 0.1 - 01:10:24
# 			Query strategy: FixedUncertainty - 01:10:24
# 			Query strategy: VariableUncertainty - 01:10:24
# 			Query strategy: Split - 01:10:24
# 			Query strategy: StreamProbabilisticAL - 01:10:25
# 			Query strategy: StreamRandomSampling - 01:10:25
# 			Query strategy: PeriodicSampling - 01:10:25
# 			Query strategy: RandomVariableUncertainty - 01:10:25
# 			Query strategy: StreamDensityBasedAL - 01:10:25
# 			Query strategy: CognitiveDualQueryStrategyRan - 01:10:25
# 			Query strategy: CognitiveDualQueryStrategyFixUn - 01:10:25
# 			Query strategy: CognitiveDualQueryStrategyRanVarUn - 01:10:25
# 			Query strategy: CognitiveDualQueryStrategyVarUn - 01:10:25
# 		Budget: 0.2 - 01:10:25
# 			Query strategy: FixedUncertainty - 01:10:25
# 			Query strategy: VariableUncertainty - 01:10:25
# 			Query strategy: Split - 01:10:25
# 			Query strategy: StreamProbabilisticAL - 01:10:25
# 			Query strategy: StreamRandomSampling - 01:10:26
# 			Query strategy: PeriodicSampling - 01:10:26
# 			Query strategy: RandomVariableUncertainty - 01:10:26
# 			Query strategy: StreamDensityBasedAL - 01:10:26
# 			Query strategy: CognitiveDualQueryStrategyRan - 01:10:26
# 			Query strategy: CognitiveDualQueryStrategyFixUn - 01:10:26
# 			Query strategy: CognitiveDualQueryStrategyRanVarUn - 01:10:26
# 			Query strategy: CognitiveDualQueryStrategyVarUn - 01:10:26
# 		Budget: 0.5 - 01:10:26
# 			Query strategy: FixedUncertainty - 01:10:26
# 			Query strategy: VariableUncertainty - 01:10:26
# 			Query strategy: Split - 01:10:26
# 			Query strategy: StreamProbabilisticAL - 01:10:26
# 			Query strategy: StreamRandomSampling - 01:10:27
# 			Query strategy: PeriodicSampling - 01:10:27
# 			Query strategy: RandomVariableUncertainty - 01:10:27
# 			Query strategy: StreamDensityBasedAL - 01:10:27
# 			Query strategy: CognitiveDualQueryStrategyRan - 01:10:27
# 			Query strategy: CognitiveDualQueryStrategyFixUn - 01:10:27
# 			Query strategy: CognitiveDualQueryStrategyRanVarUn - 01:10:27
# 			Query strategy: CognitiveDualQueryStrategyVarUn - 01:10:27
# 		Budget: 1.0 - 01:10:27
# 	Model: DecisionTree - 01:10:27
# 		Budget: 0.05 - 01:10:27
# 			Query strategy: FixedUncertainty - 01:10:27
# 			Query strategy: VariableUncertainty - 01:10:27
# 			Query strategy: Split - 01:10:27
# 			Query strategy: StreamProbabilisticAL - 01:10:28
# 			Query strategy: StreamRandomSampling - 01:10:28
# 			Query strategy: PeriodicSampling - 01:10:28
# 			Query strategy: RandomVariableUncertainty - 01:10:28
# 			Query strategy: StreamDensityBasedAL - 01:10:28
# 			Query strategy: CognitiveDualQueryStrategyRan - 01:10:28
# 			Query strategy: CognitiveDualQueryStrategyFixUn - 01:10:28
# 			Query strategy: CognitiveDualQueryStrategyRanVarUn - 01:10:28
# 			Query strategy: CognitiveDualQueryStrategyVarUn - 01:10:28
# 		Budget: 0.1 - 01:10:28
# 			Query strategy: FixedUncertainty - 01:10:28
# 			Query strategy: VariableUncertainty - 01:10:28
# 			Query strategy: Split - 01:10:28
# 			Query strategy: StreamProbabilisticAL - 01:10:29
# 			Query strategy: StreamRandomSampling - 01:10:29
# 			Query strategy: PeriodicSampling - 01:10:29
# 			Query strategy: RandomVariableUncertainty - 01:10:29
# 			Query strategy: StreamDensityBasedAL - 01:10:29
# 			Query strategy: CognitiveDualQueryStrategyRan - 01:10:29
# 			Query strategy: CognitiveDualQueryStrategyFixUn - 01:10:29
# 			Query strategy: CognitiveDualQueryStrategyRanVarUn - 01:10:30
# 			Query strategy: CognitiveDualQueryStrategyVarUn - 01:10:30
# 		Budget: 0.2 - 01:10:30
# 			Query strategy: FixedUncertainty - 01:10:30
# 			Query strategy: VariableUncertainty - 01:10:30
# 			Query strategy: Split - 01:10:30
# 			Query strategy: StreamProbabilisticAL - 01:10:30
# 			Query strategy: StreamRandomSampling - 01:10:31
# 			Query strategy: PeriodicSampling - 01:10:31
# 			Query strategy: RandomVariableUncertainty - 01:10:31
# 			Query strategy: StreamDensityBasedAL - 01:10:31
# 			Query strategy: CognitiveDualQueryStrategyRan - 01:10:31
# 			Query strategy: CognitiveDualQueryStrategyFixUn - 01:10:31
# 			Query strategy: CognitiveDualQueryStrategyRanVarUn - 01:10:31
# 			Query strategy: CognitiveDualQueryStrategyVarUn - 01:10:31
# 		Budget: 0.5 - 01:10:31
# 			Query strategy: FixedUncertainty - 01:10:31
# 			Query strategy: VariableUncertainty - 01:10:31
# 			Query strategy: Split - 01:10:31
# 			Query strategy: StreamProbabilisticAL - 01:10:31
# 			Query strategy: StreamRandomSampling - 01:10:32
# 			Query strategy: PeriodicSampling - 01:10:32
# 			Query strategy: RandomVariableUncertainty - 01:10:32
# 			Query strategy: StreamDensityBasedAL - 01:10:32
# 			Query strategy: CognitiveDualQueryStrategyRan - 01:10:32
# 			Query strategy: CognitiveDualQueryStrategyFixUn - 01:10:32
# 			Query strategy: CognitiveDualQueryStrategyRanVarUn - 01:10:32
# 			Query strategy: CognitiveDualQueryStrategyVarUn - 01:10:32
# 		Budget: 1.0 - 01:10:32
# 	Model: RandomForest - 01:10:32
# 		Budget: 0.05 - 01:10:40
# 			Query strategy: FixedUncertainty - 01:10:40
# 			Query strategy: VariableUncertainty - 01:10:40
# 			Query strategy: Split - 01:10:40
# 			Query strategy: StreamProbabilisticAL - 01:10:41
# 			Query strategy: StreamRandomSampling - 01:10:41
# 			Query strategy: PeriodicSampling - 01:10:41
# 			Query strategy: RandomVariableUncertainty - 01:10:41
# 			Query strategy: StreamDensityBasedAL - 01:10:42
# 			Query strategy: CognitiveDualQueryStrategyRan - 01:10:42
# 			Query strategy: CognitiveDualQueryStrategyFixUn - 01:10:43
# 			Query strategy: CognitiveDualQueryStrategyRanVarUn - 01:10:43
# 			Query strategy: CognitiveDualQueryStrategyVarUn - 01:10:43
# 		Budget: 0.1 - 01:10:44
# 			Query strategy: FixedUncertainty - 01:10:44
# 			Query strategy: VariableUncertainty - 01:10:44
# 			Query strategy: Split - 01:10:45
# 			Query strategy: StreamProbabilisticAL - 01:10:45
# 			Query strategy: StreamRandomSampling - 01:10:45
# 			Query strategy: PeriodicSampling - 01:10:46
# 			Query strategy: RandomVariableUncertainty - 01:10:46
# 			Query strategy: StreamDensityBasedAL - 01:10:46
# 			Query strategy: CognitiveDualQueryStrategyRan - 01:10:46
# 			Query strategy: CognitiveDualQueryStrategyFixUn - 01:10:47
# 			Query strategy: CognitiveDualQueryStrategyRanVarUn - 01:10:47
# 			Query strategy: CognitiveDualQueryStrategyVarUn - 01:10:48
# 		Budget: 0.2 - 01:10:48
# 			Query strategy: FixedUncertainty - 01:10:48
# 			Query strategy: VariableUncertainty - 01:10:48
# 			Query strategy: Split - 01:10:49
# 			Query strategy: StreamProbabilisticAL - 01:10:49
# 			Query strategy: StreamRandomSampling - 01:10:50
# 			Query strategy: PeriodicSampling - 01:10:50
# 			Query strategy: RandomVariableUncertainty - 01:10:50
# 			Query strategy: StreamDensityBasedAL - 01:10:50
# 			Query strategy: CognitiveDualQueryStrategyRan - 01:10:51
# 			Query strategy: CognitiveDualQueryStrategyFixUn - 01:10:51
# 			Query strategy: CognitiveDualQueryStrategyRanVarUn - 01:10:52
# 			Query strategy: CognitiveDualQueryStrategyVarUn - 01:10:52
# 		Budget: 0.5 - 01:10:53
# 			Query strategy: FixedUncertainty - 01:10:53
# 			Query strategy: VariableUncertainty - 01:10:53
# 			Query strategy: Split - 01:10:53
# 			Query strategy: StreamProbabilisticAL - 01:10:54
# 			Query strategy: StreamRandomSampling - 01:10:54
# 			Query strategy: PeriodicSampling - 01:10:54
# 			Query strategy: RandomVariableUncertainty - 01:10:54
# 			Query strategy: StreamDensityBasedAL - 01:10:55
# 			Query strategy: CognitiveDualQueryStrategyRan - 01:10:55
# 			Query strategy: CognitiveDualQueryStrategyFixUn - 01:10:55
# 			Query strategy: CognitiveDualQueryStrategyRanVarUn - 01:10:56
# 			Query strategy: CognitiveDualQueryStrategyVarUn - 01:10:56
# 		Budget: 1.0 - 01:10:57
# 	Model: CatBoost - 01:10:57
# 		Budget: 0.05 - 01:11:04
# 			Query strategy: FixedUncertainty - 01:11:04
# 			Query strategy: VariableUncertainty - 01:11:04
# 			Query strategy: Split - 01:11:04
# 			Query strategy: StreamProbabilisticAL - 01:11:04
# 			Query strategy: StreamRandomSampling - 01:11:05
# 			Query strategy: PeriodicSampling - 01:11:05
# 			Query strategy: RandomVariableUncertainty - 01:11:05
# 			Query strategy: StreamDensityBasedAL - 01:11:05
# 			Query strategy: CognitiveDualQueryStrategyRan - 01:11:05
# 			Query strategy: CognitiveDualQueryStrategyFixUn - 01:11:05
# 			Query strategy: CognitiveDualQueryStrategyRanVarUn - 01:11:05
# 			Query strategy: CognitiveDualQueryStrategyVarUn - 01:11:05
# 		Budget: 0.1 - 01:11:05
# 			Query strategy: FixedUncertainty - 01:11:05
# 			Query strategy: VariableUncertainty - 01:11:05
# 			Query strategy: Split - 01:11:05
# 			Query strategy: StreamProbabilisticAL - 01:11:05
# 			Query strategy: StreamRandomSampling - 01:11:05
# 			Query strategy: PeriodicSampling - 01:11:05
# 			Query strategy: RandomVariableUncertainty - 01:11:06
# 			Query strategy: StreamDensityBasedAL - 01:11:06
# 			Query strategy: CognitiveDualQueryStrategyRan - 01:11:06
# 			Query strategy: CognitiveDualQueryStrategyFixUn - 01:11:06
# 			Query strategy: CognitiveDualQueryStrategyRanVarUn - 01:11:06
# 			Query strategy: CognitiveDualQueryStrategyVarUn - 01:11:06
# 		Budget: 0.2 - 01:11:06
# 			Query strategy: FixedUncertainty - 01:11:06
# 			Query strategy: VariableUncertainty - 01:11:06
# 			Query strategy: Split - 01:11:06
# 			Query strategy: StreamProbabilisticAL - 01:11:06
# 			Query strategy: StreamRandomSampling - 01:11:06
# 			Query strategy: PeriodicSampling - 01:11:06
# 			Query strategy: RandomVariableUncertainty - 01:11:06
# 			Query strategy: StreamDensityBasedAL - 01:11:06
# 			Query strategy: CognitiveDualQueryStrategyRan - 01:11:06
# 			Query strategy: CognitiveDualQueryStrategyFixUn - 01:11:07
# 			Query strategy: CognitiveDualQueryStrategyRanVarUn - 01:11:07
# 			Query strategy: CognitiveDualQueryStrategyVarUn - 01:11:07
# 		Budget: 0.5 - 01:11:07
# 			Query strategy: FixedUncertainty - 01:11:07
# 			Query strategy: VariableUncertainty - 01:11:07
# 			Query strategy: Split - 01:11:07
# 			Query strategy: StreamProbabilisticAL - 01:11:07
# 			Query strategy: StreamRandomSampling - 01:11:07
# 			Query strategy: PeriodicSampling - 01:11:07
# 			Query strategy: RandomVariableUncertainty - 01:11:07
# 			Query strategy: StreamDensityBasedAL - 01:11:07
# 			Query strategy: CognitiveDualQueryStrategyRan - 01:11:07
# 			Query strategy: CognitiveDualQueryStrategyFixUn - 01:11:07
# 			Query strategy: CognitiveDualQueryStrategyRanVarUn - 01:11:07
# 			Query strategy: CognitiveDualQueryStrategyVarUn - 01:11:08
# 		Budget: 1.0 - 01:11:08

# %%
df = pd.read_csv(f'{results_path}/test_results.csv')

# %%
df[df['query_strategy'] == 'StreamProbabilisticAL']
# Out:
#     Unnamed: 0 dataset          model_name  \
# 0            0    iris  LogisticRegression
# 1            0    iris  LogisticRegression
# 2            0    iris  LogisticRegression
# 3            0    iris  LogisticRegression
# 5            0    iris             XGBoost
# 6            0    iris             XGBoost
# 7            0    iris             XGBoost
# 8            0    iris             XGBoost
# 10           0    iris                 SVM
# 11           0    iris                 SVM
# 12           0    iris                 SVM
# 13           0    iris                 SVM
# 15           0    iris        DecisionTree
# 16           0    iris        DecisionTree
# 17           0    iris        DecisionTree
# 18           0    iris        DecisionTree
# 20           0    iris        RandomForest
# 21           0    iris        RandomForest
# 22           0    iris        RandomForest
# 23           0    iris        RandomForest
#
#                                          model_params  initial_score  \
# 0                                           {'C': 10}            1.0
# 1                                           {'C': 10}            1.0
# 2                                           {'C': 10}            1.0
# 3                                           {'C': 10}            1.0
# 5   {'gamma': 0, 'learning_rate': 0.01, 'max_depth...            0.8
# 6   {'gamma': 0, 'learning_rate': 0.01, 'max_depth...            0.8
# 7   {'gamma': 0, 'learning_rate': 0.01, 'max_depth...            0.8
# 8   {'gamma': 0, 'learning_rate': 0.01, 'max_depth...            0.8
# 10                        {'C': 10, 'gamma': 'scale'}            1.0
# 11                        {'C': 10, 'gamma': 'scale'}            1.0
# 12                        {'C': 10, 'gamma': 'scale'}            1.0
# 13                        {'C': 10, 'gamma': 'scale'}            1.0
# 15  {'max_depth': None, 'min_samples_leaf': 1, 'mi...            1.0
# 16  {'max_depth': None, 'min_samples_leaf': 1, 'mi...            1.0
# 17  {'max_depth': None, 'min_samples_leaf': 1, 'mi...            1.0
# 18  {'max_depth': None, 'min_samples_leaf': 1, 'mi...            1.0
# 20  {'max_depth': None, 'min_samples_leaf': 2, 'mi...            1.0
# 21  {'max_depth': None, 'min_samples_leaf': 2, 'mi...            1.0
# 22  {'max_depth': None, 'min_samples_leaf': 2, 'mi...            1.0
# 23  {'max_depth': None, 'min_samples_leaf': 2, 'mi...            1.0
#
#            query_strategy  budget  percentage_queried  final_accuracy
# 0   StreamProbabilisticAL    0.05            0.100000        1.000000
# 1   StreamProbabilisticAL    0.10            0.150000        1.000000
# 2   StreamProbabilisticAL    0.20            0.208333        1.000000
# 3   StreamProbabilisticAL    0.50            0.500000        1.000000
# 5   StreamProbabilisticAL    0.05            0.058333        0.800000
# 6   StreamProbabilisticAL    0.10            0.108333        0.800000
# 7   StreamProbabilisticAL    0.20            0.200000        0.800000
# 8   StreamProbabilisticAL    0.50            0.508333        0.933333
# 10  StreamProbabilisticAL    0.05            0.041667        1.000000
# 11  StreamProbabilisticAL    0.10            0.091667        1.000000
# 12  StreamProbabilisticAL    0.20            0.183333        1.000000
# 13  StreamProbabilisticAL    0.50            0.483333        1.000000
# 15  StreamProbabilisticAL    0.05            0.050000        0.866667
# 16  StreamProbabilisticAL    0.10            0.100000        0.866667
# 17  StreamProbabilisticAL    0.20            0.200000        0.866667
# 18  StreamProbabilisticAL    0.50            0.508333        1.000000
# 20  StreamProbabilisticAL    0.05            0.050000        1.000000
# 21  StreamProbabilisticAL    0.10            0.100000        1.000000
# 22  StreamProbabilisticAL    0.20            0.191667        1.000000
# 23  StreamProbabilisticAL    0.50            0.475000        1.000000

# %%
StreamProbabilisticAL(budget=budget, metric = 'rbf', random_state=0).query

# %%
from sklearn.base import ClassifierMixin

class WrappedXGBClassifier(XGBClassifier):
    def fit(self, X, y, **kwargs):
        return super().fit(X, y, **kwargs)
    def predict(self,X, **kwargs):
        return super().predict(X, **kwargs)
    def predict_proba(self, X, **kwargs):
        return super().predict_proba(X, **kwargs)
    def score(self, X, y, **kwargs):
        return super().score(X, y, **kwargs)
    def predict_freq(self, X, **kwargs):
        return self.predict_proba(X, **kwargs)

class WrappedCatBoostClassifier(CatBoostClassifier):
    def fit(self, X, y, **kwargs):
        return super().fit(X, y, **kwargs)

    def predict(self, X, **kwargs):
        return super().predict(X, **kwargs)

    def predict_proba(self, X, **kwargs):
        return super().predict_proba(X, **kwargs)

    def score(self, X, y, **kwargs):
        return super().score(X, y, **kwargs)

    def predict_freq(self, X, **kwargs):
        return self.predict_proba(X, **kwargs)

class WrappedSklearnClassifier(ClassifierMixin):
    def __init__(self, clf):
        self.clf = clf

    def fit(self, X, y, **kwargs):
        self.clf.fit(X, y, **kwargs)
        return self

    def predict(self, X, **kwargs):
        return self.clf.predict(X, **kwargs)

    def predict_proba(self, X, **kwargs):
        return self.clf.predict_proba(X, **kwargs)

    def predict_freq(self, X, **kwargs):
        return self.predict_proba(X, **kwargs)

# %%
results_df = pd.DataFrame()

for dataset in datasets_dict.keys():
    print(f'Dataset: {dataset}')
    df = pd.read_csv(
        datasets_dict[dataset]['path'],
        header =  datasets_dict[dataset]['header']
        )

    X = df[datasets_dict[dataset]['X']]

    y = df[datasets_dict[dataset]['y']]

    X_init_train = X.iloc[:round(X.shape[0]*init_train_ratio)]
    y_init_train = y.iloc[:round(y.shape[0]*init_train_ratio)]

    X_stream = X.iloc[round(X.shape[0]*init_train_ratio):round(X.shape[0]*stream_ratio)]
    y_stream = y.iloc[round(y.shape[0]*init_train_ratio):round(y.shape[0]*stream_ratio)]

    X_stream = X_stream.to_numpy()
    y_stream = y_stream.to_numpy()

    X_final_val = X.iloc[round(X.shape[0]*stream_ratio):]
    y_final_val = y.iloc[round(y.shape[0]*stream_ratio):]

    for model_name, model_config in models.items():
        print(f'\tModel: {model_name} - {datetime.now(tz_utc_minus_3).strftime("%H:%M:%S")}')

        grid_search = GridSearchCV(model_config['model'], model_config['params'], cv=5, scoring='accuracy', n_jobs=-1, error_score = 'raise', refit=True)
        grid_search.fit(X_init_train, y_init_train)

        X_final_train = X_init_train
        y_final_train = y_init_train

        if model_name == 'XGBoost':
            pretrained_model = WrappedXGBClassifier(grid_search.best_estimator_)
        elif model_name == 'CatBoost':
            pretrained_model = WrappedCatBoostClassifier(grid_search.best_estimator_)
        else:
            pretrained_model = WrappedSklearnClassifier(grid_search.best_estimator_)

        clf_factory = lambda: SklearnClassifier(pretrained_model)

        clf_inicial = clf_factory().fit(X_init_train, y_init_train)

        y_pred = clf_inicial.predict(X_final_val)

        initial_accuracy = custom_accuracy(y_final_val, y_pred)

        for budget in budgets:
            print(f'\t\tBudget: {budget} - {datetime.now(tz_utc_minus_3).strftime("%H:%M:%S")}')
            query_strategies = {
                # 'FixedUncertainty': FixedUncertainty(budget=budget, random_state=0),
                # 'VariableUncertainty': VariableUncertainty(budget=budget, random_state=0),
                # 'Split': Split(budget=budget, random_state=0),
                'StreamProbabilisticAL': StreamProbabilisticAL(budget=budget, random_state=0),
                # 'StreamRandomSampling': StreamRandomSampling(budget=budget, random_state=0),
                # 'PeriodicSampling': PeriodicSampling(budget=budget, random_state=0),
                # 'RandomVariableUncertainty': RandomVariableUncertainty(budget=budget, random_state=0),
                # 'StreamDensityBasedAL': StreamDensityBasedAL(budget=budget, random_state=0),
                # 'CognitiveDualQueryStrategyRan': CognitiveDualQueryStrategyRan(budget=budget, random_state=0),
                # 'CognitiveDualQueryStrategyFixUn': CognitiveDualQueryStrategyFixUn(budget=budget, random_state=0),
                # 'CognitiveDualQueryStrategyRanVarUn': CognitiveDualQueryStrategyRanVarUn(budget=budget, random_state=0),
                # 'CognitiveDualQueryStrategyVarUn': CognitiveDualQueryStrategyVarUn(budget=budget, random_state=0),
            }

            if budget == 1.0:
                X_final_train = pd.concat([X_init_train, pd.DataFrame(X_stream)], axis = 0, ignore_index=True)
                y_final_train = pd.concat([y_init_train, pd.Series(y_stream)], axis = 0, ignore_index=True)

                clf = clf_factory()

                final_trained_model = clf.fit(X_final_train, y_final_train)

                y_pred = final_trained_model.predict(X_final_val)

                final_accuracy = custom_accuracy(y_final_val, y_pred)

                experiment_result = pd.DataFrame(data = {
                        'dataset': [dataset],
                        'model_name': [model_name],
                        'model_params': [str(grid_search.best_params_)],
                        'initial_score': [initial_accuracy],
                        'query_strategy': 'NONE: BUDGET = 1',
                        'budget': [budget],
                        'percentage_queried': [(X_final_train.shape[0] - X_init_train.shape[0])/(X_stream.shape[0])],
                        'final_accuracy': [final_accuracy]
                    })

                results_df = pd.concat([results_df, experiment_result], axis = 0)
                results_df.to_csv(f'{results_path}/test_results.csv')

            else:
                for query_strategy_name, query_strategy in query_strategies.items():
                    print(f'\t\t\tQuery strategy: {query_strategy_name} - {datetime.now(tz_utc_minus_3).strftime("%H:%M:%S")}')

                    X_final_train = X_init_train.to_numpy()
                    y_final_train = y_init_train.to_numpy()

                    new_X, new_y = [], []

                    for i in range(len(X_stream)):
                        x_cand = X_stream[i].reshape(1,-1)
                        y_cand = y_stream[i].reshape(1,)


                        if query_strategy_name in ('StreamProbabilisticAL'):
                            queried_indices, utilities = query_strategy.query(
                                candidates=x_cand,
                                clf=clf_inicial,
                                X=X_init_train,
                                y=y_init_train,
                                return_utilities=True,
                                fit_clf=False
                            )
                        else:
                            queried_indices, utilities = call_func(
                                query_strategy.query,
                                candidates=x_cand,
                                clf=clf_inicial,
                                return_utilities=True,
                                fit_clf=False
                            )

                        budget_manager_param_dict = {"utilities": utilities}

                        call_func(query_strategy.update,
                                    candidates = x_cand,
                                    queried_indices = queried_indices,
                                    budget_manager_param_dict=budget_manager_param_dict)

                        if len(queried_indices):
                            new_X.append(x_cand)
                            new_y.append(y_cand)

                    if new_X:
                        X_final_train = np.vstack([X_final_train] + new_X)
                        y_final_train = np.concatenate([y_final_train] + new_y, axis=0)

                    clf = clf_factory()

                    X_final_train = pd.DataFrame(X_final_train, columns=X_init_train.columns)
                    y_final_train = pd.Series(y_final_train.flatten())

                    final_trained_model = clf.fit(X_final_train, y_final_train)

                    y_pred = final_trained_model.predict(X_final_val)

                    final_accuracy = custom_accuracy(y_final_val, y_pred)

                    experiment_result = pd.DataFrame(data = {
                        'dataset': [dataset],
                        'model_name': [model_name],
                        'model_params': [str(grid_search.best_params_)],
                        'initial_score': [initial_accuracy],
                        'query_strategy': [query_strategy_name],
                        'budget': [budget],
                        'percentage_queried': [(X_final_train.shape[0] - X_init_train.shape[0])/(X_stream.shape[0])],
                        'final_accuracy': [final_accuracy]
                    })

                    results_df = pd.concat([results_df, experiment_result], axis = 0)
                    results_df.to_csv(f'{results_path}/test_results.csv')
# Out:
# Dataset: iris
# 	Model: LogisticRegression - 01:54:39
# 		Budget: 0.05 - 01:54:40
# 			Query strategy: StreamProbabilisticAL - 01:54:40
# 		Budget: 0.1 - 01:54:41
# 			Query strategy: StreamProbabilisticAL - 01:54:41
# 		Budget: 0.2 - 01:54:41
# 			Query strategy: StreamProbabilisticAL - 01:54:41
# 		Budget: 0.5 - 01:54:41
# 			Query strategy: StreamProbabilisticAL - 01:54:41
# 		Budget: 1.0 - 01:54:41
# 	Model: XGBoost - 01:54:41
# 		Budget: 0.05 - 01:54:53
# 			Query strategy: StreamProbabilisticAL - 01:54:53
# 		Budget: 0.1 - 01:54:54
# 			Query strategy: StreamProbabilisticAL - 01:54:54
# 		Budget: 0.2 - 01:54:54
# 			Query strategy: StreamProbabilisticAL - 01:54:54
# 		Budget: 0.5 - 01:54:54
# 			Query strategy: StreamProbabilisticAL - 01:54:54
# 		Budget: 1.0 - 01:54:54
# 	Model: SVM - 01:54:54
# 		Budget: 0.05 - 01:54:54
# 			Query strategy: StreamProbabilisticAL - 01:54:54
# 		Budget: 0.1 - 01:54:55
# 			Query strategy: StreamProbabilisticAL - 01:54:55
# 		Budget: 0.2 - 01:54:55
# 			Query strategy: StreamProbabilisticAL - 01:54:55
# 		Budget: 0.5 - 01:54:55
# 			Query strategy: StreamProbabilisticAL - 01:54:55
# 		Budget: 1.0 - 01:54:55
# 	Model: DecisionTree - 01:54:55
# 		Budget: 0.05 - 01:54:55
# 			Query strategy: StreamProbabilisticAL - 01:54:55
# 		Budget: 0.1 - 01:54:55
# 			Query strategy: StreamProbabilisticAL - 01:54:55
# 		Budget: 0.2 - 01:54:55
# 			Query strategy: StreamProbabilisticAL - 01:54:55
# 		Budget: 0.5 - 01:54:55
# 			Query strategy: StreamProbabilisticAL - 01:54:55
# 		Budget: 1.0 - 01:54:55
# 	Model: RandomForest - 01:54:55
# 		Budget: 0.05 - 01:55:02
# 			Query strategy: StreamProbabilisticAL - 01:55:02
# 		Budget: 0.1 - 01:55:03
# 			Query strategy: StreamProbabilisticAL - 01:55:03
# 		Budget: 0.2 - 01:55:03
# 			Query strategy: StreamProbabilisticAL - 01:55:03
# 		Budget: 0.5 - 01:55:03
# 			Query strategy: StreamProbabilisticAL - 01:55:03
# 		Budget: 1.0 - 01:55:04
# 	Model: CatBoost - 01:55:04
# 		Budget: 0.05 - 01:55:10
# 			Query strategy: StreamProbabilisticAL - 01:55:10
# ---------------------------------------------------------------------------
# CatBoostError                             Traceback (most recent call last)
# Cell In[35], line 108
#     104 y_cand = y_stream[i].reshape(1,)
#     107 if query_strategy_name in ('StreamProbabilisticAL'):
# --> 108     queried_indices, utilities = query_strategy.query(
#     109         candidates=x_cand,
#     110         clf=clf_inicial,
#     111         X=X_init_train,
#     112         y=y_init_train,
#     113         return_utilities=True,
#     114         fit_clf=False
#     115     )
#     116 else:
#     117     queried_indices, utilities = call_func(
#     118         query_strategy.query,
#     119         candidates=x_cand,
#    (...)
#     122         fit_clf=False
#     123     )
#
# File ~/.pyenv/versions/masters/lib/python3.11/site-packages/skactiveml/stream/_stream_probabilistic_al.py:183, in StreamProbabilisticAL.query(self, candidates, clf, X, y, sample_weight, fit_clf, utility_weight, return_utilities)
#     181     k_vec = n * pred_proba
#     182 else:
# --> 183     k_vec = clf.predict_freq(candidates)
#     185 utilities = cost_reduction(k_vec, prior=self.prior, m_max=self.m_max)
#     187 utilities *= utility_weight
#
# Cell In[32], line 30, in WrappedCatBoostClassifier.predict_freq(self, X, **kwargs)
#      29 def predict_freq(self, X, **kwargs):
# ---> 30     probas = self.predict_proba(X, **kwargs)
#      31     return [probas.mean(axis=0)]
#
# Cell In[32], line 24, in WrappedCatBoostClassifier.predict_proba(self, X, **kwargs)
#      23 def predict_proba(self, X, **kwargs):
# ---> 24     return super().predict_proba(X, **kwargs)
#
# File ~/.pyenv/versions/masters/lib/python3.11/site-packages/catboost/core.py:5351, in CatBoostClassifier.predict_proba(self, X, ntree_start, ntree_end, thread_count, verbose, task_type)
#    5309 def predict_proba(self, X, ntree_start=0, ntree_end=0, thread_count=-1, verbose=None, task_type="CPU"):
#    5310     """
#    5311     Predict class probability with X.
#    5312
#    (...)
#    5349             with probability for every class for each object.
#    5350     """
# -> 5351     return self._predict(X, 'Probability', ntree_start, ntree_end, thread_count, verbose, 'predict_proba', task_type)
#
# File ~/.pyenv/versions/masters/lib/python3.11/site-packages/catboost/core.py:2620, in CatBoost._predict(self, data, prediction_type, ntree_start, ntree_end, thread_count, verbose, parent_method_name, task_type)
#    2618 if verbose is None:
#    2619     verbose = False
# -> 2620 data, data_is_single_object = self._process_predict_input_data(data, parent_method_name, thread_count)
#    2621 self._validate_prediction_type(prediction_type)
#    2623 predictions = self._base_predict(data, prediction_type, ntree_start, ntree_end, thread_count, verbose, task_type)
#
# File ~/.pyenv/versions/masters/lib/python3.11/site-packages/catboost/core.py:2596, in CatBoost._process_predict_input_data(self, data, parent_method_name, thread_count, label)
#    2594 def _process_predict_input_data(self, data, parent_method_name, thread_count, label=None):
#    2595     if not self.is_fitted() or self.tree_count_ is None:
# -> 2596         raise CatBoostError(("There is no trained model to use {}(). "
#    2597                              "Use fit() to train model. Then use this method.").format(parent_method_name))
#    2598     is_single_object = _is_data_single_object(data)
#    2599     if not isinstance(data, Pool):
#
# CatBoostError: There is no trained model to use predict_proba(). Use fit() to train model. Then use this method.
